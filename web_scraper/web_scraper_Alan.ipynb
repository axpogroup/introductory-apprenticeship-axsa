# %%
import requests
import time
from bs4 import BeautifulSoup

# %%
# PART 1: FETCH ALL AK-47 SKIN NAMES FROM STEAM


print("=" * 70)
print("PART 1: COLLECTING AK-47 SKIN NAMES")
print("=" * 70)

all_skins = []
start = 0

while True:
    url = f'https://steamcommunity.com/market/search/render/?appid=730&category_730_Weapon%5B%5D=tag_weapon_ak47&norender=1&count=10&start={start}'
    response = requests.get(url, verify=False)
    data = response.json()
    
    results_raw = data.get('results', [])
    
    if not results_raw:
        break
    
    for item in results_raw:
        all_skins.append(item.get('name'))
    
    print(f'Collected: {len(all_skins)} skins so far...')
    start += 10
    time.sleep(1)

print(f'Total skins found: {len(all_skins)}')
# Out:
# ...
# PART 1: COLLECTING AK-47 SKIN NAMES
# ...
# /Users/alanomar/Documents/introductory-apprenticeship-axsa/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'steamcommunity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Collected: 10 skins so far...
# /Users/alanomar/Documents/introductory-apprenticeship-axsa/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'steamcommunity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Collected: 20 skins so far...
# ...

# %%
# PART 2: FETCH PRICE FOR EACH SKIN

print("\n" + "=" * 70)
print("PART 2: FETCHING PRICES")
print("=" * 70)

results = []

for skin in all_skins:
    url = f'https://steamcommunity.com/market/priceoverview/?appid=730&currency=1&market_hash_name={requests.utils.quote(skin)}'
    response = requests.get(url, verify=False)
    data = response.json()
    
    lowest = data.get('lowest_price', 'N/A')
    median = data.get('median_price', 'N/A')
    
    print(f'{skin}: {lowest} (median: {median})')
    results.append({'skin': skin, 'lowest': lowest, 'median': median})
    
    time.sleep(1)
# Out:
# ...
# PART 2: FETCHING PRICES
# ...
# /Users/alanomar/Documents/introductory-apprenticeship-axsa/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'steamcommunity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# AK-47 | Slate (Field-Tested): $7.19 (median: $7.28)
# /Users/alanomar/Documents/introductory-apprenticeship-axsa/.venv/lib/python3.14/site-packages/urllib3/connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'steamcommunity.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# AK-47 | Asiimov (Field-Tested): $56.23 (median: $55.55)
# ...

# %%
# PART 3: SHOW CHEAPEST AND MOST EXPENSIVE


print("\n" + "=" * 70)
print("PART 3: RESULTS")
print("=" * 70)

# Filter out skins with no price
valid = [r for r in results if r['lowest'] != 'N/A']

# Sort by price
valid.sort(key=lambda x: float(x['lowest'].replace('$', '').replace(',', '')))

print("\nTOP 5 CHEAPEST:")
for r in valid[:5]:
    print(f"  {r['skin']}: {r['lowest']}")

print("\nTOP 5 MOST EXPENSIVE:")
for r in valid[-5:]:
    print(f"  {r['skin']}: {r['lowest']}")

print(f"\nDone. {len(results)} skins scraped.")
# Out:
# ...
# PART 3: RESULTS
# ...
#
# TOP 5 CHEAPEST:
#   AK-47 | Safari Mesh (Minimal Wear): $0.36
#   AK-47 | Uncharted (Field-Tested): $1.06
#   AK-47 | Elite Build (Battle-Scarred): $2.46
#   AK-47 | Elite Build (Field-Tested): $3.35
#   StatTrak™ AK-47 | Uncharted (Field-Tested): $4.18
#
# TOP 5 MOST EXPENSIVE:
#   AK-47 | Redline (Field-Tested): $44.68
#   AK-47 | Asiimov (Field-Tested): $56.23
#   AK-47 | Nouveau Rouge (Minimal Wear): $66.10
#   AK-47 | Crane Flight (Minimal Wear): $74.00
#   AK-47 | Blue Laminate (Factory New): $86.21
#
# Done. 20 skins scraped.
